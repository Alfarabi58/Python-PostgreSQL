# %% [markdown]
# ## NAMA : ALFARABI
#
# ##### Program ini dibuat untuk melakukan cleaning, merapihkan, dan sehingga dapat dimasukan ke dalam database.

# %%
import pandas as pd

# %% [markdown]
# ## 1. Data Exploration

# %% [markdown]
# ### a. Load file data dengan Pandas lalu tampilkan data. Informasi apa yang bisa kamu sampaikan dari langkah ini?

# %% [markdown]
# informasi yang saya dapat adalah, dapat melihat banyaknya baris, kolom dan value yang terdapat dalam tabel berikut.

# %%
# untuk memanggil file dari github
file = ('https://raw.githubusercontent.com/FTDS-learning-materials/phase-0/main/src/Financials.csv')
df = pd.read_csv(file)
df
# Out:
#               Segment                   Country     Product   Discount Band   \
# 0          Government                    Canada   Carretera            None
# 1          Government                   Germany   Carretera            None
# 2           Midmarket                    France   Carretera            None
# 3           Midmarket                   Germany   Carretera            None
# 4           Midmarket                    Mexico   Carretera            None
# ..                ...                       ...          ...             ...
# 695    Small Business                    France    Amarilla            High
# 696    Small Business                    Mexico    Amarilla            High
# 697        Government                    Mexico     Montana            High
# 698        Government                    Canada       Paseo            High
# 699  Channel Partners  United States of America         VTT            High
#
# ...

# %% [markdown]
# ### b. Tampilkan informasi summary data dan berikan penjelasan mengenai temuan yang diperoleh.

# %%
# untuk menampilkan info tabel
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Segment                700 non-null    object
#  1   Country                700 non-null    object
#  2    Product               700 non-null    object
#  3    Discount Band         700 non-null    object
#  4    Units Sold            700 non-null    object
#  5    Manufacturing Price   700 non-null    object
#  6    Sale Price            700 non-null    object
#  7    Gross Sales           700 non-null    object
#  8    Discounts             700 non-null    object
#  9     Sales                700 non-null    object
#  10   COGS                  700 non-null    object
#  11   Profit                700 non-null    object
#  12  Date                   700 non-null    object
#  13  Month Number           700 non-null    int64
# ...

# %% [markdown]
# dari informasi diatas saya dapat melihat tipe data dari kolom tersebut

# %% [markdown]
# ### c. Tampilkan list nama-nama kolom dan berikan penjelasan temuan apa yang kamu dapatkan, serta berikan langkah apa selanjutnya dari temuan ini.

# %%
# untuk menampilkan nama kolom
df.columns
# Out:
# Index(['Segment', 'Country', ' Product ', ' Discount Band ', ' Units Sold ',
#        ' Manufacturing Price ', ' Sale Price ', ' Gross Sales ', ' Discounts ',
#        '  Sales ', ' COGS ', ' Profit ', 'Date', 'Month Number',
#        ' Month Name ', 'Year'],
#       dtype='object')

# %% [markdown]
# informasi yang saya dapat adalah dapat mengetahui nama-nama dari kolom, untuk langkah selanjutnya saya akan memperbaiki nama kolom dengan menghapus spasi

# %% [markdown]
# ### d. Tampilkan list nilai unik masing-masing kolom `Segment`, `Country`, `Product`, `Discount Band` dan berikan informasi apa yang dapat kamu ambil dari langkah ini.

# %%
# untuk menampilkan value unik dari kolom segment
df['Segment'].unique()
# Out:
# array(['Government', 'Midmarket', 'Channel Partners', 'Enterprise',
#        'Small Business'], dtype=object)

# %%
# untuk menampilkan value unik dari kolom country
df['Country'].unique()
# Out:
# array(['Canada', 'Germany', 'France', 'Mexico',
#        'United States of America'], dtype=object)

# %%
# untuk menampilkan value unik dari kolom product
df[' Product '].unique()
# Out:
# array([' Carretera ', ' Montana ', ' Paseo ', ' Velo ', ' VTT ',
#        ' Amarilla '], dtype=object)

# %%
# untuk menampilkan value unik dari kolom discount band
df[' Discount Band '].unique()
# Out:
# array([' None ', ' Low ', ' Medium ', ' High '], dtype=object)

# %% [markdown]
# informasi yang saya dapat dari data diatas adalah saya dapat melihat value dari kolom segment, country, product, discount band

# %% [markdown]
# ## 2. Data Cleaning

# %% [markdown]
# ### a. Manipulasi kolom meliputi penggantian nama kolom, penghapusan kolom, atau penambahan kolom

# %%
# untuk mengganti atau mengedit nama kolom
df = df.rename(columns = {' Product ':'Product', 
          ' Discount Band ':'Discount Band', 
          ' Units Sold ':'Units Sold', 
          ' Manufacturing Price ':'Manufacturing Price', 
          ' Sale Price ':'Sale Price', 
          ' Gross Sales ':'Gross Sales', 
          ' Discounts ':'Discounts', 
          '  Sales ':'Sales', 
          ' COGS ':'COGS', 
          ' Profit ':'Profit', 
          ' Month Name ':'Month Name'})

df
# Out:
#               Segment                   Country      Product Discount Band  \
# 0          Government                    Canada   Carretera          None
# 1          Government                   Germany   Carretera          None
# 2           Midmarket                    France   Carretera          None
# 3           Midmarket                   Germany   Carretera          None
# 4           Midmarket                    Mexico   Carretera          None
# ..                ...                       ...          ...           ...
# 695    Small Business                    France    Amarilla          High
# 696    Small Business                    Mexico    Amarilla          High
# 697        Government                    Mexico     Montana          High
# 698        Government                    Canada       Paseo          High
# 699  Channel Partners  United States of America         VTT          High
#
#       Units Sold Manufacturing Price Sale Price     Gross Sales  \
# ...

# %% [markdown]
# informasi yng didapat dari atas adalah kita dapat memanipulasi atau mengedit nama kolom dengan tujuan agar mempermudah dalam memasuki nama kolom yang kita inginkan

# %% [markdown]
# ### b. Penggantian tipe data yang sesuai dengan seharusnya. Untuk nilai harga dengan simbol mata uang, simbol tersebut dapat dibuang supaya dapat terkonversi ke tipe data yang seharusnya. Perhatikan format penulisan angkanya apakah ada tanda yang membuat angka hanya bisa bertipe data string. (Tambahan: Di suatu kolom yang bernilai uang, terpadat beberapa data yang mengandung karakter '(' dan ')' di dalamnya sehingga harus ditake-out karakter tersebut).

# %%
df.columns
# Out:
# Index(['Segment', 'Country', 'Product', 'Discount Band', 'Units Sold',
#        'Manufacturing Price', 'Sale Price', 'Gross Sales', 'Discounts',
#        'Sales', 'COGS', 'Profit', 'Date', 'Month Number', 'Month Name',
#        'Year'],
#       dtype='object')

# %%
# untuk mengganti karakater yang tidak diperlukan pada value kolom
df['Units Sold'] = df['Units Sold'].str.replace('$', '').str.replace(',', '').str.replace('(', '').str.replace(')', '').str.replace(' ', '').str.replace('-', '')
df['Manufacturing Price'] = df['Manufacturing Price'].str.replace('$', '').str.replace(',', '').str.replace('(', '').str.replace(')', '').str.replace(' ', '').str.replace('-', '')
df['Sale Price'] = df['Sale Price'].str.replace('$', '').str.replace(',', '').str.replace('(', '').str.replace(')', '').str.replace(' ', '').str.replace('-', '')
df['Gross Sales'] = df['Gross Sales'].str.replace('$', '').str.replace(',', '').str.replace('(', '').str.replace(')', '').str.replace(' ', '').str.replace('-', '')
df['Discounts'] = df['Discounts'].str.replace('$', '').str.replace(',', '').str.replace('(', '').str.replace(')', '').str.replace(' ', '').str.replace('-', '0')
df['Sales'] = df['Sales'].str.replace('$', '').str.replace(',', '').str.replace('(', '').str.replace(')', '').str.replace(' ', '').str.replace('-', '')
df['COGS'] = df['COGS'].str.replace('$', '').str.replace(',', '').str.replace('(', '').str.replace(')', '').str.replace(' ', '').str.replace('-', '')
df['Profit'] = df['Profit'].str.replace('$', '').str.replace(',', '').str.replace('(', '').str.replace(')', '').str.replace(' ', '').str.replace('-', '0')
df
# Out:
#               Segment                   Country      Product Discount Band  \
# 0          Government                    Canada   Carretera          None
# 1          Government                   Germany   Carretera          None
# 2           Midmarket                    France   Carretera          None
# 3           Midmarket                   Germany   Carretera          None
# 4           Midmarket                    Mexico   Carretera          None
# ..                ...                       ...          ...           ...
# 695    Small Business                    France    Amarilla          High
# 696    Small Business                    Mexico    Amarilla          High
# 697        Government                    Mexico     Montana          High
# 698        Government                    Canada       Paseo          High
# 699  Channel Partners  United States of America         VTT          High
#
#     Units Sold Manufacturing Price Sale Price Gross Sales  Discounts  \
# ...

# %% [markdown]
# informasi yang didapatkan adalah kita dapat mengganti atau menghapus karakter pada value yang tidak diperlukan

# %% [markdown]
# ### c. Cek dan handling missing value. (Hint: terdapat non-standard missing value pada kolom yang semestinya bertipe data integer, handling dapat dilakukan dengan imputasi dengan angka nol '0')

# %%
# untuk menyesuaikan tipe data
df['Units Sold'] = df['Units Sold'].astype(float)
df['Manufacturing Price'] = df['Manufacturing Price'].astype(float)
df['Sale Price'] = df['Sale Price'].astype(float)
df['Gross Sales'] = df['Gross Sales'].astype(float)
df['Discounts'] = df['Discounts'].astype(float)
df['Sales'] = df['Sales'].astype(float)
df['COGS'] = df['COGS'].astype(float)
df['Profit'] = df['Profit'].astype(float)
df['Month Number'] = pd.to_datetime(df['Month Number'])
df['Date'] = pd.to_datetime(df['Date'])

df.dtypes
# Out:
# Segment                        object
# Country                        object
# Product                        object
# Discount Band                  object
# Units Sold                    float64
# Manufacturing Price           float64
# Sale Price                    float64
# Gross Sales                   float64
# Discounts                     float64
# Sales                         float64
# COGS                          float64
# Profit                        float64
# Date                   datetime64[ns]
# Month Number           datetime64[ns]
# Month Name                     object
# Year                            int64
# dtype: object

# %% [markdown]
# diatas adalah cara mengganti untuk menyesuaikan tipe data

# %% [markdown]
# ## 3. Data Normalization

# %%
# untuk membuat data frame baru dan mencari nilai unik dari kolom
Segment_baru = pd.DataFrame(df['Segment'].unique())
Country_baru = pd.DataFrame(df['Country'].unique())
Product_baru = pd.DataFrame(df['Product'].unique())
Discount_Band_baru = pd.DataFrame(df['Discount Band'].unique())

Discount_Band_baru
# Out:
#           0
# 0     None
# 1      Low
# 2   Medium
# 3     High

# %%
# untuk menyimpan kolom dalam format cvs
Segment_baru.to_csv('Segment_baru', index = False)
Country_baru.to_csv('Country_baru', index = False)
Product_baru.to_csv('Produk_baru', index = False)
Discount_Band_baru.to_csv('Discount_Band_baru', index = False)

# %%
# untuk melakukan normalisasi
df['Segment'] = df['Segment'].str.replace('Government','1').str.replace('Midmarket','2').str.replace('Channel Partners','3').str.replace('Enterprise','4').str.replace('Small Business','5')
df['Country'] = df['Country'].str.replace('Canada','1').str.replace('Germany','2').str.replace('France','3').str.replace('Mexico','4').str.replace('United States of America','5')
df['Product'] = df['Product'].str.replace('Carretera','1').str.replace('Montana','2').str.replace('Paseo','3').str.replace('Velo','4').str.replace('VTT','5').str.replace('Amarilla','6')
df['Discount Band'] = df['Discount Band'].str.replace('None','1').str.replace('Low','2').str.replace('Medium','3').str.replace('High','4')
df
# Out:
#     Segment Country Product Discount Band  Units Sold  Manufacturing Price  \
# 0         1       1      1             1       1618.5                  3.0
# 1         1       2      1             1       1321.0                  3.0
# 2         2       3      1             1       2178.0                  3.0
# 3         2       2      1             1        888.0                  3.0
# 4         2       4      1             1       2470.0                  3.0
# ..      ...     ...     ...           ...         ...                  ...
# 695       5       3      6             4       2475.0                260.0
# 696       5       4      6             4        546.0                260.0
# 697       1       4      2             4       1368.0                  5.0
# 698       1       1      3             4        723.0                 10.0
# 699       3       5      5             4       1806.0                250.0
#
# ...

# %%
# untuk mengganti dtype pada kolom segment, country, product, discount band
df['Segment'] = df['Segment'].astype(int)
df['Country'] = df['Country'].astype(int)
df['Product'] = df['Product'].astype(int)
df['Discount Band'] = df['Discount Band'].astype(int)

df.dtypes
# Out:
# Segment                         int32
# Country                         int32
# Product                         int32
# Discount Band                   int32
# Units Sold                    float64
# Manufacturing Price           float64
# Sale Price                    float64
# Gross Sales                   float64
# Discounts                     float64
# Sales                         float64
# COGS                          float64
# Profit                        float64
# Date                   datetime64[ns]
# Month Number           datetime64[ns]
# Month Name                     object
# Year                            int64
# dtype: object

# %%
# untuk menyimpan tabel ke dalam format csv
df.to_csv('df_done', index = False)

# %% [markdown]
# cara diatas bertujuan untuk menormalisasi data yang sudah diolah sampai dengan 3NF, dan melakukan pembuatan data frame baru lalu menyimpannya dengan format cvs

# %% [markdown]
# ## 4. Relational Database & SQL

# %% [markdown]
# Dikerjakan di SQL

# %% [markdown]
# ## 5.Pengujian Database

# %% [markdown]
# ### a. Berikan tabel yang berisikan informasi total profit yang didapatkan di tiap jenis segmentasi. Jangan ambil data yang tidak diskon.

# %% [markdown]
# ```SQL
# SELECT Segment, SUM(Profit) AS total_profit
# FROM df
# WHERE Discounts > 0
# GROUP BY Segment
# ORDER BY 1 DESC;
# ```

# %% [markdown]
# berikut adalah cara untuk mencari informasi total profit yang didapatkan di setiap jenis segmentasi yang memiliki diskon

# %% [markdown]
# ### b. Berikan tabel yang berisikan informasi rangkuman statistik yang memuat nilai rata-rata, min, dan max (dijadikan dalam kolom yang berbeda) dari Sales masing-masing negara.

# %% [markdown]
# ```SQL
# SELECT Country,
#     AVG(Sales) AS rata_rata_sales,
#     MIN(Sales) AS sales_minimum,
#     MAX(Sales) AS sales_maksimum
# FROM df
# GROUP BY Country
# ORDER BY 1 DESC;
#
# COPY (
#     SELECT Segment, SUM(Profit) AS total_profit
#     FROM df
#     WHERE Discounts > 0
#     GROUP BY Segment
# ) TO 'C:\tmp\Tabel_1A' WITH CSV HEADER;
#
# COPY (
#     SELECT Country, AVG(Sales) AS rata_rata_sales, MIN(Sales) AS sales_minimum, MAX(Sales) AS sales_maksimum
#     FROM df
#     GROUP BY Country
# ) TO 'C:\tmp\Tabel_1B' WITH CSV HEADER;
# ```

# %%
# untuk melihat hasil query pada Tabel 1A
uji_data1 = pd.read_csv('C:\\tmp\Tabel_1A')
uji_data1
# Out:
#    segment  total_profit
# 0        1   10270950.18
# 1        3    1150321.14
# 2        5    3848268.50
# 3        4     879096.88
# 4        2     563253.09

# %%
# untuk melihat hasil query pada Tabel 1B
uji_data2 = pd.read_csv('C:\\tmp\Tabel_1B')
uji_data2
# Out:
#    country  rata_rata_sales  sales_minimum  sales_maksimum
# 0        1    177768.963500        1655.08       1038082.5
# 1        3    173958.373500        1763.86        962500.0
# 2        5    178784.501286        1730.54       1159200.0
# 3        4    149638.229357        2508.66        848172.5
# 4        2    167895.291571        1685.60       1017338.0

# %% [markdown]
# berikut ada cara untuk mencari nilai average, minimum, dan maksimal dari sebuah value, lalu menyimpannya dengan format csv, dan selanjutnya melakukan pengujian data untuk melihat hasil query
